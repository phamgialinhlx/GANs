# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load the images
image1 = mpimg.imread('./assets/gan_mnist_real.png')
image2 = mpimg.imread('./assets/gan_mnist_fake.png')
image3 = mpimg.imread('./assets/dcgan_mnist_fake.png')

# Create a figure with three subplots
fig, axes = plt.subplots(1, 3, figsize=(12, 6))

# Display the first image
axes[0].imshow(image1)
axes[0].set_title('Real images in MNIST dataset')
axes[0].axis('off')

# Display the second image
axes[1].imshow(image2)
axes[1].set_title('Fake images generated by GAN')
axes[1].axis('off')

# Display the third image
axes[2].imshow(image3)
axes[2].set_title('Fake images generated by DCGAN')
axes[2].axis('off')

# Adjust the spacing between subplots
plt.subplots_adjust(wspace=0.05)

# Show the figure
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load the images
image1 = mpimg.imread('./assets/dcgan_fashionmnist_real.png')
image2 = mpimg.imread('./assets/dcgan_fashionmnist_fake.png')

# Create a figure with three subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Display the first image
axes[0].imshow(image1)
axes[0].axis('off')
axes[0].set_title('Real images in Fashion MNIST dataset')

# Display the second image
axes[1].imshow(image2)
axes[1].set_title('Fake images generated by DCGAN')
axes[1].axis('off')


# Adjust the spacing between subplots
plt.subplots_adjust(wspace=0.05)

# Show the figure
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load the images
image1 = mpimg.imread('./assets/dcgan_gender_real.png')
image2 = mpimg.imread('./assets/dcgan_gender_fake.png')

# Create a figure with three subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Display the first image
axes[0].imshow(image1)
axes[0].set_title('Real images in GENDER dataset')
axes[0].axis('off')

# Display the second image
axes[1].imshow(image2)
axes[1].set_title('Fake images generated by DCGAN')
axes[1].axis('off')


# Adjust the spacing between subplots
plt.subplots_adjust(wspace=0.05)

# Show the figure
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load the images
image1 = mpimg.imread('./assets/cgan_mnist_real.png')
image2 = mpimg.imread('./assets/cgan_mnist_fake.png')

# Create a figure with three subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Display the first image
axes[0].imshow(image1)
axes[0].axis('off')
axes[0].set_title('Real images in MNIST dataset')

# Display the second image
axes[1].imshow(image2)
axes[1].set_title('Fake images generated by cGAN')
axes[1].axis('off')


# Adjust the spacing between subplots
plt.subplots_adjust(wspace=0.05)

# Show the figure
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load the images
image1 = mpimg.imread('./assets/cgan_fashionmnist_real.png')
image2 = mpimg.imread('./assets/cgan_fashionmnist_fake.png')

# Create a figure with three subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Display the first image
axes[0].imshow(image1)
axes[0].axis('off')
axes[0].set_title('Real images in MNIST dataset')

# Display the second image
axes[1].imshow(image2)
axes[1].set_title('Fake images generated by cGAN')
axes[1].axis('off')


# Adjust the spacing between subplots
plt.subplots_adjust(wspace=0.05)

# Show the figure
plt.show()
